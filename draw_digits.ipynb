# %%
import numpy as np
from pandas import read_csv
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

rawtrain = read_csv('train.csv', nrows = 10000).values

pca = PCA(n_components=196)
pca.fit(rawtrain[:, 1:])
# Out:
# PCA(copy=True, n_components=196, whiten=False)

# %%
n = np.random.randint(0, rawtrain.shape[0])

sample = rawtrain[n, 1:]
sample = np.reshape(sample, (28, 28))

# %matplotlib inline
plot = plt.imshow(sample)
plot.set_cmap('gray_r')
plt.show()

# %%
sample = rawtrain[n, 1:]

sample = pca.transform(sample)

sample = np.reshape(sample, (14, 14))

# %matplotlib inline
plot = plt.imshow(sample)
plot.set_cmap('gray_r')
plt.show()

# %%
# testing progress bar

import pyprind
import time
from datetime import datetime

start = datetime.now()
for j in range(3):
    print('Epoch ' + str(j + 1))
    for i in pyprind.prog_bar(range(100), stream=1):
        time.sleep(0.01)

overalltime = datetime.now() - start
print('Overall time:', overalltime)
# Out:
# Epoch 1
# 0%                          100%
# [##############################] | ETA: 00:00:00
# Total time elapsed: 00:00:01
# Epoch 2
# 0%                          100%
# [##############################] | ETA: 00:00:00
# Total time elapsed: 00:00:01
# Epoch 3
# 0%                          100%
# [##############################] | ETA: 00:00:00
# Total time elapsed: 00:00:01
# Overall time: 0:00:03.083774
